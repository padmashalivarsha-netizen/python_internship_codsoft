# %% [markdown]
# <a href="https://colab.research.google.com/github/padmashalivarsha-netizen/python_internship_codsoft/blob/main/password.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import string

length = int(input("Enter password length: "))

characters = (
    string.ascii_letters +
    string.digits +
    string.punctuation
)

password = ''.join(random.choice(characters) for _ in range(length))

print("\nGenerated Password:")
print(password)
# Out:
# Enter password length: 8
#
# Generated Password:
# @ikoHYge
